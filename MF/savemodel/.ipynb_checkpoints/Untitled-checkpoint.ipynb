# %%
import pandas as pd
import numpy as np

# %%
mean = pd.read_csv('overall_mean.model',names=['overall_mean'])
mean
# Out:
#    overall_mean
# 0       0.10968

# %%
p_q = pd.read_csv('p_Q.model', names=['penalty_Q'])
p_q
# Out:
#       penalty_Q
# 0      0.000241
# 1      0.009265
# 2     -0.049886
# 3     -0.002766
# 4     -0.000768
# 5     -0.060359
# 6     -0.011458
# 7     -0.077885
# 8     -0.008044
# 9      0.015694
# 10     0.006083
# 11     0.004412
# 12    -0.036189
# 13    -0.033941
# 14    -0.010818
# 15     0.014184
# 16    -0.016681
# 17     0.000614
# 18    -0.102767
# 19     0.009093
# 20     0.010251
# 21     0.000691
# 22    -0.003128
# 23    -0.008886
# 24     0.007265
# 25    -0.001076
# 26     0.012844
# 27     0.021890
# 28    -0.042072
# 29     0.004853
# ...         ...
# 7678   0.001603
# 7679  -0.000197
# 7680  -0.000197
# 7681  -0.000198
# 7682  -0.000198
# 7683   0.001602
# 7684  -0.000197
# 7685  -0.000198
# 7686   0.001602
# 7687   0.001602
# 7688  -0.000198
# 7689  -0.000197
# 7690  -0.000198
# 7691  -0.000197
# 7692  -0.000198
# 7693  -0.000198
# 7694  -0.000198
# 7695   0.001602
# 7696  -0.000197
# 7697   0.001602
# 7698  -0.000198
# 7699  -0.000197
# 7700  -0.000198
# 7701  -0.000198
# 7702   0.001603
# 7703  -0.000197
# 7704   0.001602
# 7705   0.001602
# 7706   0.001602
# 7707   0.001603
#
# [7708 rows x 1 columns]

# %%
p_u = pd.read_csv('p_U.model', names=['penalty_U'])
p_u
# Out:
#        penalty_U
# 0      -0.007898
# 1       0.065721
# 2       0.005687
# 3      -0.006184
# 4      -0.001383
# 5      -0.002766
# 6      -0.006100
# 7      -0.003951
# 8      -0.007113
# 9       0.001032
# 10     -0.011382
# 11      0.045546
# 12     -0.005730
# 13     -0.003161
# 14     -0.001975
# 15     -0.009676
# 16      0.035492
# 17     -0.000790
# 18     -0.006168
# 19     -0.004345
# 20      0.015235
# 21     -0.001185
# 22     -0.006322
# 23     -0.000197
# 24     -0.005972
# 25     -0.008101
# 26      0.004412
# 27      0.007070
# 28     -0.002674
# 29      0.003623
# ...          ...
# 27097  -0.000198
# 27098  -0.000197
# 27099  -0.000197
# 27100  -0.000197
# 27101  -0.000197
# 27102  -0.000198
# 27103  -0.000198
# 27104  -0.000198
# 27105  -0.000198
# 27106  -0.000198
# 27107  -0.000198
# 27108  -0.000197
# 27109  -0.000197
# 27110  -0.000198
# 27111  -0.000197
# 27112  -0.000198
# 27113  -0.000197
# 27114  -0.000197
# 27115  -0.000197
# 27116  -0.000198
# 27117  -0.000197
# 27118   0.001602
# 27119  -0.000197
# 27120   0.001602
# 27121  -0.000197
# 27122  -0.000198
# 27123  -0.000197
# 27124  -0.000198
# 27125  -0.000197
# 27126  -0.000198
#
# [27127 rows x 1 columns]

# %%
q_m = pd.read_csv('Q_Maxtrix.model',names = ['q_m'])
q_m
# Out:
#            q_m
# 0     0.013092
# 1     0.004812
# 2     0.004247
# 3     0.008696
# 4     0.006163
# 5     0.008137
# 6     0.007921
# 7    -0.000082
# 8     0.013551
# 9     0.012159
# 10    0.009412
# 11    0.010639
# 12    0.012103
# 13    0.003037
# 14    0.008386
# 15    0.007091
# 16    0.001475
# 17    0.011733
# 18    0.008821
# 19    0.000536
# 20    0.010944
# 21    0.003292
# 22    0.002457
# 23    0.003177
# 24    0.011219
# 25    0.010349
# 26    0.009532
# 27    0.007454
# 28    0.007427
# 29    0.003865
# ...        ...
# 7678  0.011792
# 7679  0.005976
# 7680  0.000790
# 7681  0.009620
# 7682  0.007826
# 7683  0.012010
# 7684  0.001748
# 7685  0.009846
# 7686  0.010301
# 7687  0.003958
# 7688  0.005741
# 7689  0.000499
# 7690  0.005874
# 7691  0.003007
# 7692  0.009456
# 7693  0.014088
# 7694  0.010983
# 7695  0.004644
# 7696  0.004267
# 7697  0.004485
# 7698  0.010149
# 7699  0.002835
# 7700  0.003784
# 7701  0.005491
# 7702  0.009762
# 7703  0.009080
# 7704  0.009489
# 7705  0.013062
# 7706  0.009063
# 7707  0.007123
#
# [7708 rows x 1 columns]

# %%
u_m = pd.read_csv('U_Maxtrix.model',names = ['u_m'])
float(u_m.loc[3])
# Out:
# 0.0005800299382790001

# %%
def load_hashdata(path):
    d = {}
    try:
        file_question_hash = open(path,'r')
    except Exception as e:
        raise ValueError('Cannot find txt file pls run Map_data.py script first')
    for fileline in file_question_hash:
        fileline = fileline.strip('\r\n').split('\t')
        d[fileline[0]] = int(fileline[1])

    return d

# %%
question_hash_path = '../data/invited_question_info_hash.txt'
user_hash_path = '../data/invited_user_info_hash.txt'

# %%
dict_q = load_hashdata(question_hash_path)
dict_u = load_hashdata(user_hash_path)

# %%
def predict_load(user, question):
    score = float(mean.loc[0]) + float(p_u.loc[user]) + float(p_q.loc[question]) + np.dot(np.matrix(u_m.loc[user]), np.matrix(q_m.loc[question]).T)
    score = max(score, 0.)
    score = min(score, 1.)
    return float(score)

# %%
result_path = 'result_loadmodel.txt'
    # NN_CF_Feature = '../data/NN_CF_Feature.txt'
# test_submit_path = '../data/submit/test_submit.txt'

result_file = open(result_path,'w')
    # NN_CF_Feature_file = open(NN_CF_Feature,'w')
# test_submit_file = open(test_submit_path,'w')

# test_file = open('../data/test_nolabel.txt','r')
vali_file = open('../data/validate_nolabel.txt','r')
    # train_file = open('../data/invited_info_NN_bj.txt','r')

result_file.write('qid,uid,label\n')
# test_submit_file.write('qid,uid.label\n')
is_head = True
for fileline in vali_file:
    if is_head:
        is_head = False
        continue
    else:
        fileline = fileline.strip('\n\r').split(',')
        q_id = fileline[0]
        u_id = fileline[1]

        try:
#             score = MF.predict(dict_u[u_id], dict_q[q_id])
            score = predict_load(dict_u[u_id], dict_q[q_id])
        except Exception as e:
            score = 0.
#             print q_id + ',' + u_id + " Unable to predict"

        if score < 1e-5:
            score = 0.

        result = q_id + "," + u_id + "," + str(score) + '\n'
        result_file.write(result)
result_file.close()
